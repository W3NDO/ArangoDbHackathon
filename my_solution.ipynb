# %% [markdown]
# # My submission to the ArangoDb Hackathon
# ## By Patrick Wendo

# %% [markdown]
# The dataset used in this notebook is available on Kaggle [here](https://www.kaggle.com/datasets/andreuvallhernndez/myanimelist)

# %%
# !pip3 install kagglehub pandas numpy networkx matplotlib nx_arangodb
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: kagglehub in /home/w3ndo/.local/lib/python3.10/site-packages (0.3.7)
# Requirement already satisfied: pandas in /home/w3ndo/.local/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: numpy in /home/w3ndo/.local/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: networkx in /home/w3ndo/.local/lib/python3.10/site-packages (3.4.2)
# Requirement already satisfied: matplotlib in /home/w3ndo/.local/lib/python3.10/site-packages (3.10.0)
# Collecting nx_arangodb
#   Downloading nx_arangodb-1.3.0-py3-none-any.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 KB 480.5 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: model-signing in /home/w3ndo/.local/lib/python3.10/site-packages (from kagglehub) (0.2.0)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from kagglehub) (2.25.1)
# Requirement already satisfied: tqdm in /home/w3ndo/.local/lib/python3.10/site-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: packaging in /home/w3ndo/.local/lib/python3.10/site-packages (from kagglehub) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/w3ndo/.local/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /home/w3ndo/.local/lib/python3.10/site-packages (from pandas) (2025.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/w3ndo/.local/lib/python3.10/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: contourpy>=1.0.1 in /home/w3ndo/.local/lib/python3.10/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3/dist-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: fonttools>=4.22.0 in /home/w3ndo/.local/lib/python3.10/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: cycler>=0.10 in /home/w3ndo/.local/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pillow>=8 in /home/w3ndo/.local/lib/python3.10/site-packages (from matplotlib) (11.1.0)
# Collecting networkx
#   Downloading networkx-3.4-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 3.0 MB/s eta 0:00:0000:0100:01
# Collecting adbnx-adapter~=5.0.5
#   Downloading adbnx_adapter-5.0.6-py3-none-any.whl (21 kB)
# Collecting phenolrs~=0.5
#   Downloading phenolrs-0.5.9-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 3.6 MB/s eta 0:00:0000:0100:01
# Collecting python-arango~=8.1
#   Downloading python_arango-8.1.4-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.5/116.5 KB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: setuptools>=45 in /usr/lib/python3/dist-packages (from adbnx-adapter~=5.0.5->nx_arangodb) (59.6.0)
# Requirement already satisfied: rich>=12.5.1 in /home/w3ndo/.local/lib/python3.10/site-packages (from adbnx-adapter~=5.0.5->nx_arangodb) (13.9.4)
# Collecting requests
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 KB 3.2 MB/s eta 0:00:00
# Collecting numpy
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 5.8 MB/s eta 0:00:0000:0100:01
# Collecting importlib_metadata>=4.7.1
#   Downloading importlib_metadata-8.6.1-py3-none-any.whl (26 kB)
# Collecting requests_toolbelt
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 KB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: PyJWT in /usr/lib/python3/dist-packages (from python-arango~=8.1->nx_arangodb) (2.3.0)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/lib/python3/dist-packages (from python-arango~=8.1->nx_arangodb) (1.26.5)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (146 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.1/146.1 KB 3.2 MB/s eta 0:00:0000:01
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests->kagglehub) (2020.6.20)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->kagglehub) (3.3)
# Requirement already satisfied: typing-extensions in /home/w3ndo/.local/lib/python3.10/site-packages (from model-signing->kagglehub) (4.12.2)
# Requirement already satisfied: sigstore in /home/w3ndo/.local/lib/python3.10/site-packages (from model-signing->kagglehub) (3.6.1)
# Requirement already satisfied: cryptography in /home/w3ndo/.local/lib/python3.10/site-packages (from model-signing->kagglehub) (44.0.0)
# Requirement already satisfied: in-toto-attestation in /home/w3ndo/.local/lib/python3.10/site-packages (from model-signing->kagglehub) (0.9.3)
# Collecting zipp>=3.20
#   Downloading zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/w3ndo/.local/lib/python3.10/site-packages (from rich>=12.5.1->adbnx-adapter~=5.0.5->nx_arangodb) (2.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/w3ndo/.local/lib/python3.10/site-packages (from rich>=12.5.1->adbnx-adapter~=5.0.5->nx_arangodb) (3.0.0)
# Requirement already satisfied: cffi>=1.12 in /home/w3ndo/.local/lib/python3.10/site-packages (from cryptography->model-signing->kagglehub) (1.17.1)
# Requirement already satisfied: protobuf in /home/w3ndo/.local/lib/python3.10/site-packages (from in-toto-attestation->model-signing->kagglehub) (5.29.3)
# Requirement already satisfied: sigstore-rekor-types==0.0.18 in /home/w3ndo/.local/lib/python3.10/site-packages (from sigstore->model-signing->kagglehub) (0.0.18)
# Requirement already satisfied: id>=1.1.0 in /home/w3ndo/.local/lib/python3.10/site-packages (from sigstore->model-signing->kagglehub) (1.5.0)
# Requirement already satisfied: pyasn1~=0.6 in /home/w3ndo/.local/lib/python3.10/site-packages (from sigstore->model-signing->kagglehub) (0.6.1)
# Requirement already satisfied: platformdirs~=4.2 in /home/w3ndo/.local/lib/python3.10/site-packages (from sigstore->model-signing->kagglehub) (4.3.6)
# Requirement already satisfied: pyOpenSSL>=23.0.0 in /home/w3ndo/.local/lib/python3.10/site-packages (from sigstore->model-signing->kagglehub) (25.0.0)
# Requirement already satisfied: sigstore-protobuf-specs==0.3.2 in /home/w3ndo/.local/lib/python3.10/site-packages (from sigstore->model-signing->kagglehub) (0.3.2)
# Requirement already satisfied: rfc8785~=0.1.2 in /home/w3ndo/.local/lib/python3.10/site-packages (from sigstore->model-signing->kagglehub) (0.1.4)
# Requirement already satisfied: tuf~=5.0 in /home/w3ndo/.local/lib/python3.10/site-packages (from sigstore->model-signing->kagglehub) (5.1.0)
# Requirement already satisfied: rfc3161-client~=0.1.2 in /home/w3ndo/.local/lib/python3.10/site-packages (from sigstore->model-signing->kagglehub) (0.1.2)
# Requirement already satisfied: importlib_resources~=5.7 in /home/w3ndo/.local/lib/python3.10/site-packages (from sigstore->model-signing->kagglehub) (5.13.0)
# Requirement already satisfied: pydantic<3,>=2 in /home/w3ndo/.local/lib/python3.10/site-packages (from sigstore->model-signing->kagglehub) (2.10.6)
# Requirement already satisfied: betterproto==2.0.0b6 in /home/w3ndo/.local/lib/python3.10/site-packages (from sigstore-protobuf-specs==0.3.2->sigstore->model-signing->kagglehub) (2.0.0b6)
# Requirement already satisfied: grpclib<0.5.0,>=0.4.1 in /home/w3ndo/.local/lib/python3.10/site-packages (from betterproto==2.0.0b6->sigstore-protobuf-specs==0.3.2->sigstore->model-signing->kagglehub) (0.4.7)
# Requirement already satisfied: pycparser in /home/w3ndo/.local/lib/python3.10/site-packages (from cffi>=1.12->cryptography->model-signing->kagglehub) (2.22)
# Requirement already satisfied: mdurl~=0.1 in /home/w3ndo/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=12.5.1->adbnx-adapter~=5.0.5->nx_arangodb) (0.1.2)
# Requirement already satisfied: pydantic-core==2.27.2 in /home/w3ndo/.local/lib/python3.10/site-packages (from pydantic<3,>=2->sigstore->model-signing->kagglehub) (2.27.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/w3ndo/.local/lib/python3.10/site-packages (from pydantic<3,>=2->sigstore->model-signing->kagglehub) (0.7.0)
# Requirement already satisfied: securesystemslib~=1.0 in /home/w3ndo/.local/lib/python3.10/site-packages (from tuf~=5.0->sigstore->model-signing->kagglehub) (1.2.0)
# Requirement already satisfied: email-validator>=2.0.0 in /home/w3ndo/.local/lib/python3.10/site-packages (from pydantic<3,>=2->sigstore->model-signing->kagglehub) (2.2.0)
# Requirement already satisfied: dnspython>=2.0.0 in /home/w3ndo/.local/lib/python3.10/site-packages (from email-validator>=2.0.0->pydantic<3,>=2->sigstore->model-signing->kagglehub) (2.7.0)
# Requirement already satisfied: multidict in /home/w3ndo/.local/lib/python3.10/site-packages (from grpclib<0.5.0,>=0.4.1->betterproto==2.0.0b6->sigstore-protobuf-specs==0.3.2->sigstore->model-signing->kagglehub) (6.1.0)
# Requirement already satisfied: h2<5,>=3.1.0 in /home/w3ndo/.local/lib/python3.10/site-packages (from grpclib<0.5.0,>=0.4.1->betterproto==2.0.0b6->sigstore-protobuf-specs==0.3.2->sigstore->model-signing->kagglehub) (4.2.0)
# Requirement already satisfied: hpack<5,>=4.1 in /home/w3ndo/.local/lib/python3.10/site-packages (from h2<5,>=3.1.0->grpclib<0.5.0,>=0.4.1->betterproto==2.0.0b6->sigstore-protobuf-specs==0.3.2->sigstore->model-signing->kagglehub) (4.1.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /home/w3ndo/.local/lib/python3.10/site-packages (from h2<5,>=3.1.0->grpclib<0.5.0,>=0.4.1->betterproto==2.0.0b6->sigstore-protobuf-specs==0.3.2->sigstore->model-signing->kagglehub) (6.1.0)
# Installing collected packages: zipp, numpy, networkx, charset-normalizer, requests, importlib_metadata, requests_toolbelt, python-arango, phenolrs, adbnx-adapter, nx_arangodb
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.2
#     Uninstalling numpy-2.2.2:
#       Successfully uninstalled numpy-2.2.2
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.4.2
#     Uninstalling networkx-3.4.2:
#       Successfully uninstalled networkx-3.4.2
# Successfully installed adbnx-adapter-5.0.6 charset-normalizer-3.4.1 importlib_metadata-8.6.1 networkx-3.4 numpy-1.26.4 nx_arangodb-1.3.0 phenolrs-0.5.9 python-arango-8.1.4 requests-2.32.3 requests_toolbelt-1.0.0 zipp-3.21.0

# %%
from arango import ArangoClient

import networkx as nx
import nx_arangodb as nxadb
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from random import randint
import ast
import re

anime = pd.read_csv(
    "./datasets/myanimelist/anime.csv"
)

manga = pd.read_csv(
    "./datasets/myanimelist/manga.csv"
)

anime.info()
manga.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24985 entries, 0 to 24984
# Data columns (total 39 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   anime_id          24985 non-null  int64
#  1   title             24985 non-null  object
#  2   type              24927 non-null  object
#  3   score             16050 non-null  float64
#  4   scored_by         24985 non-null  int64
#  5   status            24985 non-null  object
#  6   episodes          24438 non-null  float64
#  7   start_date        24110 non-null  object
#  8   end_date          22215 non-null  object
#  9   source            21424 non-null  object
#  10  members           24985 non-null  int64
#  11  favorites         24985 non-null  int64
#  12  episode_duration  24387 non-null  object
#  13  total_duration    24162 non-null  object
#  14  rating            24405 non-null  object
#  15  sfw               24985 non-null  bool
#  16  approved          24985 non-null  bool
#  17  created_at        24985 non-null  object
#  18  updated_at        24985 non-null  object
#  19  start_year        20301 non-null  float64
#  20  start_season      20301 non-null  object
#  21  real_start_date   24110 non-null  object
#  22  real_end_date     22215 non-null  object
#  23  broadcast_day     3450 non-null   object
#  24  broadcast_time    3313 non-null   object
#  25  genres            24985 non-null  object
#  26  themes            24985 non-null  object
#  27  demographics      24985 non-null  object
#  28  studios           24985 non-null  object
#  29  producers         24985 non-null  object
#  30  licensors         24985 non-null  object
#  31  synopsis          20492 non-null  object
#  32  background        2450 non-null   object
#  33  main_picture      24831 non-null  object
#  34  url               24985 non-null  object
#  35  trailer_url       4724 non-null   object
#  36  title_english     10402 non-null  object
#  37  title_japanese    24895 non-null  object
#  38  title_synonyms    24985 non-null  object
# dtypes: bool(2), float64(3), int64(4), object(30)
# memory usage: 7.1+ MB
#    manga_id                                            title   type  score  \
# 0         2                                          Berserk  manga   9.47
# 1        13                                        One Piece  manga   9.22
# 2      1706  JoJo no Kimyou na Bouken Part 7: Steel Ball Run  manga   9.30
# 3      4632                                   Oyasumi Punpun  manga   9.02
# 4        25                              Fullmetal Alchemist  manga   9.03
#
#    scored_by                status  volumes  chapters  start_date    end_date  \
# 0     319696  currently_publishing      NaN       NaN  1989-08-25         NaN
# 1     355375  currently_publishing      NaN       NaN  1997-07-22         NaN
# 2     151433              finished     24.0      96.0  2004-01-19  2011-04-19
# 3     168459              finished     13.0     147.0  2007-03-15  2013-11-02
# 4     153151              finished     27.0     116.0  2001-07-12  2010-09-11
#
#    members  favorites   sfw  approved          created_at_before  \
# 0   643969     119470  True      True  2007-07-17 20:14:45+00:00
# 1   579557     111462  True      True  2007-07-17 20:14:45+00:00
# 2   248511      41713  True      True  2007-10-07 08:14:20+00:00
# 3   413897      49361  True      True  2008-02-03 15:54:30+00:00
# 4   284027      29634  True      True  2007-07-17 20:14:45+00:00
#
#                   updated_at real_start_date real_end_date  \
# 0  2023-04-01 00:19:31+00:00      1989-08-25           NaN
# 1  2023-06-24 12:39:48+00:00      1997-07-22           NaN
# 2  2023-04-02 18:07:42+00:00      2004-01-19    2011-04-19
# 3  2023-04-02 18:09:11+00:00      2007-03-15    2013-11-02
# 4  2023-05-27 17:21:27+00:00      2001-07-12    2010-09-11
#
#                                               genres  \
# 0  ['Action', 'Adventure', 'Award Winning', 'Dram...
# 1                 ['Action', 'Adventure', 'Fantasy']
# 2  ['Action', 'Adventure', 'Mystery', 'Supernatur...
# 3                         ['Drama', 'Slice of Life']
# 4  ['Action', 'Adventure', 'Award Winning', 'Dram...
#
#                                               themes           demographics  \
# 0  ['Gore', 'Military', 'Mythology', 'Psychologic...             ['Seinen']
# 1                                                 []            ['Shounen']
# 2                                     ['Historical']  ['Seinen', 'Shounen']
# 3                                  ['Psychological']             ['Seinen']
# 4                                       ['Military']            ['Shounen']
#
#                                              authors  \
# 0  [{'id': 1868, 'first_name': 'Kentarou', 'last_...
# 1  [{'id': 1881, 'first_name': 'Eiichiro', 'last_...
# 2  [{'id': 2619, 'first_name': 'Hirohiko', 'last_...
# 3  [{'id': 2836, 'first_name': 'Inio', 'last_name...
# 4  [{'id': 1874, 'first_name': 'Hiromu', 'last_na...
#
#               serializations  \
# 0           ['Young Animal']
# 1  ['Shounen Jump (Weekly)']
# 2             ['Ultra Jump']
# 3      ['Big Comic Spirits']
# 4         ['Shounen Gangan']
#
#                                             synopsis  \
# 0  Guts, a former mercenary now known as the "Bla...
# 1  Gol D. Roger, a man referred to as the "King o...
# 2  In the American Old West, the world's greatest...
# 3  Punpun Onodera is a normal 11-year-old boy liv...
# 4  Alchemists are knowledgeable and naturally tal...
#
#                                           background  \
# 0  Berserk won the Award for Excellence at the si...
# 1  One Piece is the highest selling manga series ...
# 2  JoJo no Kimyou na Bouken Part 7: Steel Ball Ru...
# 3  Oyasumi Punpun was originally serialized in Yo...
# 4  Hagane no Renkinjutsushi won the 49th Shogakuk...
#
#                                         main_picture  \
# 0  https://cdn.myanimelist.net/images/manga/1/157...
# 1  https://cdn.myanimelist.net/images/manga/2/253...
# 2  https://cdn.myanimelist.net/images/manga/3/179...
# 3  https://cdn.myanimelist.net/images/manga/3/266...
# 4  https://cdn.myanimelist.net/images/manga/3/243...
#
#                                                  url        title_english  \
# 0            https://myanimelist.net/manga/2/Berserk              Berserk
# 1         https://myanimelist.net/manga/13/One_Piece            One Piece
# 2  https://myanimelist.net/manga/1706/JoJo_no_Kim...                  NaN
# 3  https://myanimelist.net/manga/4632/Oyasumi_Punpun     Goodnight Punpun
# 4  https://myanimelist.net/manga/25/Fullmetal_Alc...  Fullmetal Alchemist
#
#                     title_japanese  \
# 0                            ベルセルク
# 1                        ONE PIECE
# 2  ジョジョの奇妙な冒険 Part7 STEEL BALL RUN
# 3                         おやすみプンプン
# 4                           鋼の錬金術師
#
#                                       title_synonyms
# 0                         ['Berserk: The Prototype']
# 1                                                 []
# 2  ["JoJo's Bizarre Adventure Part 7: Steel Ball ...
# 3                                                 []
# 4  ['Full Metal Alchemist', 'Hagane no Renkinjuts...

# %% [markdown]
# ### Data Exploration

# %% [markdown]
# - We have 2 datasets, anime and manga.
# - These are both relational datasets with a single entry having multiple values. We need to figure out how to represent this data as a graph.
#
# #### Our Strategy.
# - We could represent this as an attributed graph with node attributes and edge attributes. An **attributed graph** is one where aside from node labels, or edge labels, a node or an edge will also have additional metadata. For example, in a graph about people, we could have a node with the label "Anna" with attributes `{position: "CEO", start_date: "2019-08-19"}`.
#
# - The node label would be the name of the anime/manga. We could also have some columns be extracted to nodes of their own. For instance, an anime could fall into multiple genres. We could have each of those as a separate node. Similarly for columns like studios, themes, producers, licensors and demographics.

# %%
# Exploration of the anime dataset
pd.set_option("display.max.columns", None)
[anime.shape, manga.shape]
# Out:
# [(24985, 39), (64833, 30)]

# %% [markdown]
# - The anime dataset has about **24,985 rows with 39 columns**, while the manga dataset has **64,833 rows and 30 columns**

# %%
anime.head()
# Out:
#    anime_id                               title   type  score  scored_by  \
# 0      5114    Fullmetal Alchemist: Brotherhood     tv   9.10    2037075
# 1     11061              Hunter x Hunter (2011)     tv   9.04    1671587
# 2     38524  Shingeki no Kyojin Season 3 Part 2     tv   9.05    1491491
# 3      9253                         Steins;Gate     tv   9.07    1348232
# 4     28851                      Koe no Katachi  movie   8.94    1540277
#
#             status  episodes  start_date    end_date        source  members  \
# 0  finished_airing      64.0  2009-04-05  2010-07-04         manga  3206028
# 1  finished_airing     148.0  2011-10-02  2014-09-24         manga  2688079
# 2  finished_airing      10.0  2019-04-29  2019-07-01         manga  2133927
# 3  finished_airing      24.0  2011-04-06  2011-09-14  visual_novel  2463954
# 4  finished_airing       1.0  2016-09-17  2016-09-17         manga  2218467
#
#    favorites episode_duration   total_duration rating   sfw  approved  \
# 0     219036  0 days 00:24:20  1 days 01:57:20      r  True      True
# 1     202109  0 days 00:23:37  2 days 10:15:16  pg_13  True      True
# 2      55644  0 days 00:23:55  0 days 03:59:10      r  True      True
# 3     184312  0 days 00:24:20  0 days 09:44:00  pg_13  True      True
# 4      84124  0 days 02:10:03  0 days 02:10:03  pg_13  True      True
#
#                   created_at                 updated_at  start_year  \
# 0  2008-08-21 03:35:22+00:00  2023-04-02 18:07:03+00:00      2009.0
# 1  2011-07-27 08:41:39+00:00  2023-04-02 18:11:36+00:00      2011.0
# 2  2018-10-14 18:13:45+00:00  2023-04-02 18:10:19+00:00      2019.0
# 3  2010-07-26 09:23:40+00:00  2023-04-02 18:08:42+00:00      2011.0
# 4  2014-12-15 08:00:46+00:00  2023-04-02 18:15:50+00:00      2016.0
#
#   start_season real_start_date real_end_date broadcast_day broadcast_time  \
# 0       spring      2009-04-05    2010-07-04        sunday       17:00:00
# 1         fall      2011-10-02    2014-09-24        sunday       10:55:00
# 2       spring      2019-04-29    2019-07-01        monday       00:10:00
# 3       spring      2011-04-06    2011-09-14     wednesday       02:05:00
# 4       summer      2016-09-17    2016-09-17           NaN            NaN
#
#                                         genres  \
# 0  ['Action', 'Adventure', 'Drama', 'Fantasy']
# 1           ['Action', 'Adventure', 'Fantasy']
# 2                          ['Action', 'Drama']
# 3              ['Drama', 'Sci-Fi', 'Suspense']
# 4                   ['Award Winning', 'Drama']
#
#                              themes demographics              studios  \
# 0                      ['Military']  ['Shounen']            ['Bones']
# 1                                []  ['Shounen']         ['Madhouse']
# 2  ['Gore', 'Military', 'Survival']  ['Shounen']       ['Wit Studio']
# 3  ['Psychological', 'Time Travel']           []        ['White Fox']
# 4              ['Romantic Subtext']  ['Shounen']  ['Kyoto Animation']
#
#                                            producers  \
# 0  ['Aniplex', 'Square Enix', 'Mainichi Broadcast...
# 1   ['VAP', 'Nippon Television Network', 'Shueisha']
# 2  ['Production I.G', 'Dentsu', 'Mainichi Broadca...
# 3  ['Frontier Works', 'Media Factory', 'Kadokawa ...
# 4  ['Shochiku', 'Pony Canyon', 'Kodansha', 'ABC A...
#
#                               licensors  \
# 0  ['Funimation', 'Aniplex of America']
# 1                         ['VIZ Media']
# 2                        ['Funimation']
# 3                        ['Funimation']
# 4          ['Eleven Arts', 'NYAV Post']
#
#                                             synopsis  \
# 0  After a horrific alchemy experiment goes wrong...
# 1  Hunters devote themselves to accomplishing haz...
# 2  Seeking to restore humanity's diminishing hope...
# 3  Eccentric scientist Rintarou Okabe has a never...
# 4  As a wild youth, elementary school student Sho...
#
#                                           background  \
# 0                                                NaN
# 1                                                NaN
# 2  Shingeki no Kyojin adapts content from volumes...
# 3  Steins;Gate is based on 5pb. and Nitroplus' vi...
# 4  Koe no Katachi won the following awards: Japan...
#
#                                         main_picture  \
# 0  https://cdn.myanimelist.net/images/anime/1208/...
# 1  https://cdn.myanimelist.net/images/anime/1337/...
# 2  https://cdn.myanimelist.net/images/anime/1517/...
# 3  https://cdn.myanimelist.net/images/anime/1935/...
# 4  https://cdn.myanimelist.net/images/anime/1122/...
#
#                                                  url  \
# 0  https://myanimelist.net/anime/5114/Fullmetal_A...
# 1  https://myanimelist.net/anime/11061/Hunter_x_H...
# 2  https://myanimelist.net/anime/38524/Shingeki_n...
# 3     https://myanimelist.net/anime/9253/Steins_Gate
# 4  https://myanimelist.net/anime/28851/Koe_no_Kat...
#
#                                    trailer_url  \
# 0  https://www.youtube.com/watch?v=--IcmZkvL0Q
# 1  https://www.youtube.com/watch?v=D9iTQRB4XRk
# 2  https://www.youtube.com/watch?v=hKHepjfj5Tw
# 3  https://www.youtube.com/watch?v=27OZc-ku6is
# 4  https://www.youtube.com/watch?v=XBNWo25izJ8
#
#                       title_english              title_japanese  \
# 0  Fullmetal Alchemist: Brotherhood  鋼の錬金術師 FULLMETAL ALCHEMIST
# 1                   Hunter x Hunter    HUNTER×HUNTER（ハンター×ハンター）
# 2   Attack on Titan Season 3 Part 2        進撃の巨人 Season3 Part.2
# 3                       Steins;Gate                 STEINS;GATE
# 4                    A Silent Voice                         聲の形
#
#                                       title_synonyms
# 0  ['Hagane no Renkinjutsushi: Fullmetal Alchemis...
# 1                                     ['HxH (2011)']
# 2                                                 []
# 3                                                 []
# 4                             ['The Shape of Voice']

# %%
manga.head()
# Out:
#    manga_id                                            title   type  score  \
# 0         2                                          Berserk  manga   9.47
# 1        13                                        One Piece  manga   9.22
# 2      1706  JoJo no Kimyou na Bouken Part 7: Steel Ball Run  manga   9.30
# 3      4632                                   Oyasumi Punpun  manga   9.02
# 4        25                              Fullmetal Alchemist  manga   9.03
#
#    scored_by                status  volumes  chapters  start_date    end_date  \
# 0     319696  currently_publishing      NaN       NaN  1989-08-25         NaN
# 1     355375  currently_publishing      NaN       NaN  1997-07-22         NaN
# 2     151433              finished     24.0      96.0  2004-01-19  2011-04-19
# 3     168459              finished     13.0     147.0  2007-03-15  2013-11-02
# 4     153151              finished     27.0     116.0  2001-07-12  2010-09-11
#
#    members  favorites   sfw  approved          created_at_before  \
# 0   643969     119470  True      True  2007-07-17 20:14:45+00:00
# 1   579557     111462  True      True  2007-07-17 20:14:45+00:00
# 2   248511      41713  True      True  2007-10-07 08:14:20+00:00
# 3   413897      49361  True      True  2008-02-03 15:54:30+00:00
# 4   284027      29634  True      True  2007-07-17 20:14:45+00:00
#
#                   updated_at real_start_date real_end_date  \
# 0  2023-04-01 00:19:31+00:00      1989-08-25           NaN
# 1  2023-06-24 12:39:48+00:00      1997-07-22           NaN
# 2  2023-04-02 18:07:42+00:00      2004-01-19    2011-04-19
# 3  2023-04-02 18:09:11+00:00      2007-03-15    2013-11-02
# 4  2023-05-27 17:21:27+00:00      2001-07-12    2010-09-11
#
#                                               genres  \
# 0  ['Action', 'Adventure', 'Award Winning', 'Dram...
# 1                 ['Action', 'Adventure', 'Fantasy']
# 2  ['Action', 'Adventure', 'Mystery', 'Supernatur...
# 3                         ['Drama', 'Slice of Life']
# 4  ['Action', 'Adventure', 'Award Winning', 'Dram...
#
#                                               themes           demographics  \
# 0  ['Gore', 'Military', 'Mythology', 'Psychologic...             ['Seinen']
# 1                                                 []            ['Shounen']
# 2                                     ['Historical']  ['Seinen', 'Shounen']
# 3                                  ['Psychological']             ['Seinen']
# 4                                       ['Military']            ['Shounen']
#
#                                              authors  \
# 0  [{'id': 1868, 'first_name': 'Kentarou', 'last_...
# 1  [{'id': 1881, 'first_name': 'Eiichiro', 'last_...
# 2  [{'id': 2619, 'first_name': 'Hirohiko', 'last_...
# 3  [{'id': 2836, 'first_name': 'Inio', 'last_name...
# 4  [{'id': 1874, 'first_name': 'Hiromu', 'last_na...
#
#               serializations  \
# 0           ['Young Animal']
# 1  ['Shounen Jump (Weekly)']
# 2             ['Ultra Jump']
# 3      ['Big Comic Spirits']
# 4         ['Shounen Gangan']
#
#                                             synopsis  \
# 0  Guts, a former mercenary now known as the "Bla...
# 1  Gol D. Roger, a man referred to as the "King o...
# 2  In the American Old West, the world's greatest...
# 3  Punpun Onodera is a normal 11-year-old boy liv...
# 4  Alchemists are knowledgeable and naturally tal...
#
#                                           background  \
# 0  Berserk won the Award for Excellence at the si...
# 1  One Piece is the highest selling manga series ...
# 2  JoJo no Kimyou na Bouken Part 7: Steel Ball Ru...
# 3  Oyasumi Punpun was originally serialized in Yo...
# 4  Hagane no Renkinjutsushi won the 49th Shogakuk...
#
#                                         main_picture  \
# 0  https://cdn.myanimelist.net/images/manga/1/157...
# 1  https://cdn.myanimelist.net/images/manga/2/253...
# 2  https://cdn.myanimelist.net/images/manga/3/179...
# 3  https://cdn.myanimelist.net/images/manga/3/266...
# 4  https://cdn.myanimelist.net/images/manga/3/243...
#
#                                                  url        title_english  \
# 0            https://myanimelist.net/manga/2/Berserk              Berserk
# 1         https://myanimelist.net/manga/13/One_Piece            One Piece
# 2  https://myanimelist.net/manga/1706/JoJo_no_Kim...                  NaN
# 3  https://myanimelist.net/manga/4632/Oyasumi_Punpun     Goodnight Punpun
# 4  https://myanimelist.net/manga/25/Fullmetal_Alc...  Fullmetal Alchemist
#
#                     title_japanese  \
# 0                            ベルセルク
# 1                        ONE PIECE
# 2  ジョジョの奇妙な冒険 Part7 STEEL BALL RUN
# 3                         おやすみプンプン
# 4                           鋼の錬金術師
#
#                                       title_synonyms
# 0                         ['Berserk: The Prototype']
# 1                                                 []
# 2  ["JoJo's Bizarre Adventure Part 7: Steel Ball ...
# 3                                                 []
# 4  ['Full Metal Alchemist', 'Hagane no Renkinjuts...

# %% [markdown]
# ##### Data Fix #1
# - Fix string that look like lists, `"[list, item]" -> ["list", "item"]`. This will allow us to use the #explode() function later when creating data in NetworkX

# %%
anime_columns_to_fix = ["genres", "themes", "demographics", "title_synonyms", "studios"]
manga_columns_to_fix = ["genres", "themes", "demographics", "authors"]
print("Initial Data anime Type: \n", anime.loc[1:2]['title_synonyms'].apply(type))
print("Initial Data manga Type: \n", manga.loc[1:2]['authors'].apply(type))

def rewrite_anime(col):
    anime[col] = anime[col].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

def rewrite_manga(col):
    manga[col] = manga[col].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

for col in anime_columns_to_fix:
    rewrite_anime(col)

for col in manga_columns_to_fix:
    rewrite_manga(col)

print("After Fix anime Data: \n", anime.loc[1:2]['title_synonyms'].apply(type))
print("After Fix manga Data: \n", manga.loc[1:2]['authors'].apply(type))
# Out:
# Initial Data anime Type:
#  1    <class 'list'>
# 2    <class 'list'>
# Name: title_synonyms, dtype: object
# Initial Data manga Type:
#  1    <class 'list'>
# 2    <class 'list'>
# Name: authors, dtype: object
# After Fix anime Data:
#  1    <class 'list'>
# 2    <class 'list'>
# Name: title_synonyms, dtype: object
# After Fix manga Data:
#  1    <class 'list'>
# 2    <class 'list'>
# Name: authors, dtype: object

# %%
anime_subset = anime.loc[0:5]
exploded = anime_subset.explode('themes') # fails because genres is a string
exploded['themes']
# Out:
# 0            Military
# 1                 NaN
# 2                Gore
# 2            Military
# 2            Survival
# 3       Psychological
# 3         Time Travel
# 4    Romantic Subtext
# 5    Romantic Subtext
# Name: themes, dtype: object

# %%
## Identify Key groups in the following columns: "genres", "themes", "demographics", "studios". These could be shared between anime entries.

genre_explode = anime.explode('genres')
genre_grouped_data = genre_explode.groupby("genres")
anime_genres = genre_grouped_data.groups.keys()
print("Genres: ", list(set(list(genre_grouped_data.groups.keys()))))

theme_explode = anime.explode('themes')
theme_grouped_data = theme_explode.groupby("themes")
anime_themes = theme_grouped_data.groups.keys()
print("Themes: ", list(set(list(theme_grouped_data.groups.keys()))))

demographics_explode = anime.explode('demographics')
demographic_grouped_data = demographics_explode.groupby("demographics")
anime_demographics = demographic_grouped_data.groups.keys()
print("Demographics: ", list(set(list(demographic_grouped_data.groups.keys()))))

studios_explode = anime.explode('studios')
studio_grouped_data = studios_explode.groupby("studios")
anime_studios = studio_grouped_data.groups.keys()
print("Studios: ", list(set(list(studio_grouped_data.groups.keys()))))
# Out:
# Genres:  ['Ecchi', 'Slice of Life', 'Action', 'Sci-Fi', 'Adventure', 'Horror', 'Suspense', 'Award Winning', 'Comedy', 'Avant Garde', 'Boys Love', 'Drama', 'Sports', 'Erotica', 'Girls Love', 'Fantasy', 'Supernatural', 'Romance', 'Mystery', 'Hentai', 'Gourmet']
# Themes:  ['Anthropomorphic', 'Martial Arts', 'Music', 'Childcare', 'Historical', 'Parody', 'Team Sports', 'Vampire', 'Space', 'Harem', 'Mythology', 'Crossdressing', 'CGDCT', 'Pets', 'Romantic Subtext', 'Workplace', 'Love Polygon', 'Gore', 'High Stakes Game', 'Mahou Shoujo', 'Reincarnation', 'Medical', 'Psychological', 'Delinquents', 'Racing', 'Iyashikei', 'Detective', 'Military', 'Strategy Game', 'Visual Arts', 'Time Travel', 'Idols (Male)', 'Mecha', 'Survival', 'Samurai', 'School', 'Performing Arts', 'Educational', 'Isekai', 'Gag Humor', 'Otaku Culture', 'Super Power', 'Organized Crime', 'Reverse Harem', 'Video Game', 'Combat Sports', 'Showbiz', 'Magical Sex Shift', 'Idols (Female)', 'Adult Cast']
# Demographics:  ['Seinen', 'Kids', 'Josei', 'Shounen', 'Shoujo']
# Studios:  ['pH Studio', 'TYO Animations', 'Animaruya', 'Garden Culture', 'Kung Fu Frog Animation', 'Office Take Off', 'Goto Inc.', 'Three-d', 'Adonero', 'High Energy Studio', 'Sunflowers', 'Alice Production', 'OZ', 'Nekonigashi Inc.', 'Egg Firm', 'Sasayuri', 'Future Planet', 'Quyue Technology', 'Miyu Productions', 'Haoliners Animation League', 'Larx Entertainment', 'C&S Production', 'Robot Communications', 'View Works', 'Tryforce', 'Poly Animation', 'Story Effect', 'BreakBottle', 'Dangun Pictures', 'Gonzo', 'V-sign', 'Imagineer', 'ANIDO FILM', 'Guo Pengzi Studio', 'Dancing CG Studio', 'Shanghai Hippo Animation', 'HMCH', 'L²Studio', 'The Answer Studio', 'iDRAGONS Creative Studio', 'Wako Productions', 'Arvo Animation', 'FILMONY', 'Zero-G', 'J.C.F.', 'Studio Flag', '2:10 AM Animation', 'Anon Pictures', 'Zyc', 'Enishiya', 'ASK Animation Studio', 'Assez Finaud Fabric', 'Kate Arrow', 'Quebico', 'Yi Chen Animation', 'team Yamahitsuji', 'BUDDHA INC.', 'AIC Spirits', 'Arch', 'Starry Cube', 'YURUPPE Inc.', 'Studio Add', 'Queen Bee', 'Darts', 'FIREBUG', 'IMAGICA Lab.', 'TthunDer Animation', "Steve N' Steven", 'Kuri Jikken Manga Kobo', 'Animation 21', 'PINE JAM', 'domerica', 'Nice Boat Animation', 'Digital Media Lab', 'Studio Izena', 'Animation Planet', 'Marza Animation Planet', 'Nur', 'Joker Films', 'Studio Take Off', 'Giga Production', 'Movic', 'Heart & Soul Animation', 'D & D Pictures', 'HM Heros', 'Dyna Method', 'CANDY BOX', 'XFLAG Pictures', 'Quad', 'Fuji TV', 'J.K.I', 'Ai Si Animation Studio', 'FUNNY MOVIE', 'Shengying Animation', 'Studio 3Hz', 'Liberty Animation Studio', 'Qubic Pictures', 'TNK', 'Studio Massket', 'Artland', 'Hayabusa Film', 'MAT', 'Boyan Pictures', 'Nomad', 'Sakura Create', 'Samsara Animation Studio', 'Namu Animation', 'Encourage Films', 'Kami Kukan', 'Rising Force', 'Space-X', 'Studio Hibari', 'Drawing and Manual', 'CLAP', 'Kaname Productions', 'Production IMS', 'Qiyuan Yinghua', 'Studio Pivote', 'The Monk Studios', 'Issen', 'Oriental Creative Color', 'Pmats9 studio', '8bit', 'Misogo Animation Studio', 'Eiken', 'Eshoya Honpo', 'Gakken', 'MoMo Production', 'A-Real', 'Platinum Vision', 'Triple X', 'Shogakukan Music & Digital Entertainment', 'WHOPPERS', 'Gravity Well', 'HoriPro', 'Strawberry Meets Pictures', 'Frontier Works', 'Moss Design Unit', 'Rockwell Eyes', 'Studio Moriken', 'AIC PLUS+', 'Geek Toys', 'Hotline', 'Akatsuki', 'Geno Studio', 'MI', 'AIC Takarazuka', 'Gathering', 'C and R', 'KAGAYA Studio', 'Studio Kai', 'Studio Live', 'Wolf Smoke Studio', 'Lesprit', 'Studio Jemi', 'FLAGSHIP LINE', 'LB Commerce', 'Coastline Animation Studio', 'Flint Sugar', 'Green Monster Team', 'Image Kei', 'Kachidoki Studio', 'Magic Bus', 'Voil', 'Venet', 'Charaction', 'Studio Ten Carat', 'Aurum Production', 'Welz Animation Studios', 'Nippon Animation', 'Myung Films', 'Shion', '81 Produce', 'HORNETS', 'Colored Pencil Animation', 'Okuruto Noboru', 'GAV Video', 'Directions', 'Liyu Culture', 'Office Takeout', 'Seven Arcs Pictures', 'Studio Gadget', 'yell', 'Anima&Co.', 'JM Animation', 'Yamiken', 'AION Studio', 'Nihikime no Dozeu', 'Chaos Project', 'Dongwoo A&E', 'Unend', 'HOTZIPANG', 'Actas', 'Soft Garage', 'C2C', 'Knack Productions', 'Graphinica', 'PoRO', 'Sanrio', 'T.P.O', 'Congrong Film', 'Studio Daisy', 'Nihon Ad Systems', 'TOHO animation STUDIO', 'Ark', 'Millepensee', 'Slow Studio', 'Ashi Productions', 'Meruhensha', 'Space Neko Company', 'TANOsim', 'StoryRiders Co. Ltd.', 'Hal Film Maker', 'Tokyo Media Connections', 'Marvy Jack', 'Studio Korumi', 'Creative Power Entertaining', 'MASTER LIGHTS', 'Irawias', 'Saigo no Shudan', 'Milky Cartoon', 'Onion Studio', 'Studio Coa', 'DAX Production', 'New Generation', 'MMDGP', 'Shuka', 'Imagica', 'Mikimoto Production', 'Studio Crocodile', 'Tele-Cartoon Japan', 'Shinjukuza', 'Creators Dot Com', 'JJJOY Animation Studios', 'Piko Studio', 'Planet', 'Xiaoming Taiji', 'Studio 9 Maiami', 'Grom', 'October Media', 'Tezuka Productions', 'Ai Yume Mai', 'Mouse', 'Rocen', 'Garyuu Studio', 'Studio Jam', 'Acc ...

# %% [markdown]
# ##### Authors
# - The author field in Manga datasets should be extracted into it's own dataset. Each author will be a node on it's own. They may be shared across datasets. The node label will be the id with attributes being first name, last name and role.

# %%
manga_authors = manga["authors"]
manga_authors.head()[0]
# Out:
# [{'id': 1868,
#   'first_name': 'Kentarou',
#   'last_name': 'Miura',
#   'role': 'Story & Art'},
#  {'id': 49592, 'first_name': '', 'last_name': 'Studio Gaga', 'role': 'Art'}]
